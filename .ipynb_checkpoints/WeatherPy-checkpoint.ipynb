# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from pprint import pprint
from urllib.error import HTTPError

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_longs and cities
lat_longs = []
cities = []

# Create a set of random lat and long combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_longs = zip(lats, longs)

# Identify nearest city for each lat, long combination
for lat_long in lat_longs:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": api_key}

# %%
weather_df = pd.DataFrame()
weather_df['City'] = cities
weather_df['Cloudiness'] = ""
weather_df['Country'] = ""
weather_df['Date'] = ""
weather_df['Humidity'] = ""
weather_df['Lat'] = ""
weather_df['Long'] = ""
weather_df['Max Temp'] = ""
weather_df['Wind Speed'] = ""

#array that will hold the data pulled from the get request for each city
i = 0 #use i as counter for record number since idexes may not match the record number if we skip a record
print("Beginning Data Retrieval")
print("------------------------")
for index, row in weather_df.iterrows():
    #tries to get request the weather for the current city, appends info, and prints processing record number and city name
    try:
        current_weather= owm.get_current(row[0], **settings)
        weather_df.loc[index, 'Cloudiness']= current_weather["clouds"]["all"]
        weather_df.loc[index, 'Country']= current_weather["sys"]["country"]
        weather_df.loc[index, 'Date']=current_weather["dt"]
        weather_df.loc[index, 'Humidity']=current_weather["main"]["humidity"]
        weather_df.loc[index, 'Lat']=current_weather["coord"]["lat"]
        weather_df.loc[index, 'Long']=current_weather["coord"]["lon"]
        weather_df.loc[index, 'Max Temp']=current_weather["main"]["temp_max"]
        weather_df.loc[index, 'Wind Speed']=current_weather["wind"]["speed"]
        print(f"Processing Record {i%50} of Set {i//50 +1} | {row[0]}")
        i = i + 1
    #if gets HTTPError because no data for that city, will print city not found and continues on
    except HTTPError:
        print(f"City not found. Skipping...")
        weather_df.loc[index, 'Cloudiness']= None
    time.sleep(1)
print("------------------------")  
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 1 | busselton
# Processing Record 1 of Set 1 | roald
# City not found. Skipping...
# Processing Record 2 of Set 1 | ashqelon
# Processing Record 3 of Set 1 | cam ranh
# Processing Record 4 of Set 1 | lantawan
# Processing Record 5 of Set 1 | burgeo
# Processing Record 6 of Set 1 | saint-philippe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 1 | kawalu
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | conceicao da barra
# City not found. Skipping...
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 14 of Set 1 | butembo
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | airai
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | ambovombe
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | samarai
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | weymouth
# Processing Record 26 of Set 1 | sitka
# City not found. Skipping...
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | neryungri
# Processing Record 30 of Set 1 | kaltan
# Processing Record 31 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 32 of Set 1 | kysyl-syr
# Processing Record 33 of Set 1 | geraldton
# Processing Record 34 of Set 1 | hwange
# Processing Record 35 of Set 1 | chernenko
# Processing Record 36 of Set 1 | alenquer
# Processing Record 37 of Set 1 | tarakan
# Processing Record 38 of Set 1 | kholm
# Processing Record 39 of Set 1 | ribeira grande
# City not found. Skipping...
# Processing Record 40 of Set 1 | bronnoysund
# Processing Record 41 of Set 1 | port hedland
# Processing Record 42 of Set 1 | bonavista
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | hasaki
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | esperance
# Processing Record 47 of Set 1 | ahome
# Processing Record 48 of Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 49 of Set 1 | the pas
# Processing Record 0 of Set 2 | tiksi
# Processing Record 1 of Set 2 | pocone
# City not found. Skipping...
# Processing Record 2 of Set 2 | princeton
# Processing Record 3 of Set 2 | nome
# Processing Record 4 of Set 2 | nuuk
# Processing Record 5 of Set 2 | pudozh
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | batagay
# Processing Record 8 of Set 2 | guerrero negro
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | miri
# Processing Record 12 of Set 2 | den helder
# Processing Record 13 of Set 2 | sorland
# City not found. Skipping...
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | ahipara
# City not found. Skipping...
# Processing Record 16 of Set 2 | chapais
# City not found. Skipping...
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | yulara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 2 | leningradskiy
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | cabo san lucas
# Processing Record 22 of Set 2 | dikson
# Processing Record 23 of Set 2 | gamba
# Processing Record 24 of Set 2 | sasovo
# Processing Record 25 of Set 2 | panjab
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | syracuse
# Processing Record 28 of Set 2 | gympie
# Processing Record 29 of Set 2 | nadym
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | vila velha
# Processing Record 32 of Set 2 | port hawkesbury
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | oktyabrskoye
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | norman wells
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | kolda
# Processing Record 40 of Set 2 | kudahuvadhoo
# Processing Record 41 of Set 2 | praia
# Processing Record 42 of Set 2 | tuatapere
# Processing Record 43 of Set 2 | hay river
# Processing Record 44 of Set 2 | awjilah
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | hargeysa
# Processing Record 47 of Set 2 | cape town
# Processing Record 48 of Set 2 | pasinler
# Processing Record 49 of Set 2 | parana
# Processing Record 0 of Set 3 | coihaique
# Processing Record 1 of Set 3 | kodiak
# Processing Record 2 of Set 3 | lazaro cardenas
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | comodoro rivadavia
# Processing Record 5 of Set 3 | serenje
# Processing Record 6 of Set 3 | saint-joseph
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | tasiilaq
# Processing Record 9 of Set 3 | laguna
# Processing Record 10 of Set 3 | vao
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | shasta lake
# Processing Record 13 of Set 3 | luderitz
# Processing Record 14 of Set 3 | sheopur
# Processing Record 15 of Set 3 | natal
# Processing Record 16 of Set 3 | road town
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | pacific grove
# Processing Record 19 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 20 of Set 3 | antalaha
# City not found. Skipping...
# Processing Record 21 of Set 3 | aguimes
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | honningsvag
# Processing Record 24 of Set 3 | kyabe
# Processing Record 25 of Set 3 | khandyga
# Processing Record 26 of Set 3 | caravelas
# Processing Record 27 of Set 3 | the valley
# Processing Record 28 of Set 3 | vangaindrano
# City not found. Skipping...
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | narsaq
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | springbok
# City not found. Skipping...
# Processing Record 33 of Set 3 | lugus
# Processing Record 34 of Set 3 | karratha
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | nemuro
# Processing Record 37 of Set 3 | vila franca do campo
# Processing Record 38 of Set 3 | minot
# Processing Record 39 of Set 3 | kano
# Processing Record 40 of Set 3 | stephenville
# Processing Record 41 of Set 3 | ranong
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | southbridge
# City not found. Skipping...
# Processing Record 44 of Set 3 | srednekolymsk
# Processing Record 45 of Set 3 | durban
# Processing Record 46 of Set 3 | abu kamal
# Processing Record 47 of Set 3 | hambantota
# Processing Record 48 of Set 3 | yeppoon
# Processing Record 49 of Set 3 | hamilton
# Processing Record 0 of Set 4 | souillac
# Processing Record 1 of Set 4 | santa maria
# Processing Record 2 of Set 4 | plouzane
# Processing Record 3 of Set 4 | husavik
# Processing Record 4 of Set 4 | bathsheba
# Processing Record 5 of Set 4 | mayumba
# City not found. Skipping...
# Processing Record 6 of Set 4 | yakeshi
# Processing Record 7 of Set 4 | morondava
# Processing Record 8 of Set 4 | odenton
# Processing Record 9 of Set 4 | constitucion
# Processing Record 10 of Set 4 | verkhnyaya inta
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | porbandar
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | kiunga
# Processing Record 15 of Set 4 | punta cardon
# Processing Record 16 of Set 4 | uglegorsk
# Processing Record 17 of Set 4 | camacha
# Processing Record 18 of Set 4 | terra santa
# Processing Record 19 of Set 4 | necochea
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | xiongyue
# Processing Record 22 of Set 4 | tiznit
# Processing Record 23 of Set 4 | arrifes
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | marawi
# Processing Record 26 of Set 4 | shubarkuduk
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | cuamba
# Processing Record 29 of Set 4 | chokurdakh
# Processing Record 30 of Set 4 | chingirlau
# Processing Record 31 of Set 4 | coquimbo
# Processing Record 32 of Set 4 | meru
# Processing Record 33 of Set 4 | katangli
# Processing Record 34 of Set 4 | conway
# Processing Record 35 of Set 4 | alyangula
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | haines junction
# Processing Record 38 of Set 4 | hobart
# Processing Record 39 of Set 4 | kiama
# City not found. Skipping...
# Processing Record 40 of Set 4 | touros
# Processing Record 41 of Set 4 | araouane
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | kaeo
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | huarmey
# Processing Record 46 of Set 4 | itajuba
# Processing Record 47 of Set 4 | san quintin
# Processing Record 48 of Set 4 | shirokiy
# Processing Record 49 of Set 4 | karpathos
# City not found. Skipping...
# Processing Record 0 of Set 5 | aripuana
# City not found. Skipping...
# Processing Record 1 of Set 5 | la ronge
# City not found. Skipping...
# Processing Record 2 of Set 5 | ola
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | ostrovnoy
# City not found. Skipping...
# Processing Record 5 of Set 5 | kompaniyivka
# Processing Record 6 of Set 5 | alpoyeca
# Processing Record 7 of Set 5 | vieques
# Processing Record 8 of Set 5 | ereymentau
# Processing Record 9 of Set 5 | ekhabi
# City not found. Skipping...
# Processing Record 10 of Set 5 | talnakh
# Processing Record 11 of Set 5 | sept-iles
# Processing Record 12 of Set 5 | veraval
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | wadi musa
# Processing Record 15 of Set 5 | nanortalik
# Processing Record 16 of Set 5 | saint-pierre
# City not found. Skipping...
# Processing Record 17 of Set 5 | bundaberg
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | bethel
# Processing Record 20 of Set 5 | lompoc
# Processing Record 21 of Set 5 | abhar
# Processing Record 22 of Set 5 | plettenberg bay
# Processing Record 23 of Set 5 | faisalabad
# City not found. Skipping...
# Processing Record 24 of Set 5 | broken hill
# Processing Record 25 of Set 5 | impfondo
# Processing Record 26 of Set 5 | kirakira
# Processing Record 27 of Set 5 | egvekinot
# Processing Record 28 of Set 5 | barrow
# Processing Record 29 of Set 5 | goderich
# Processing Record 30 of Set 5 | soro
# Processing Record 31 of Set 5 | tongliao
# Processing Record 32 of Set 5 | tezu
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | oriximina
# Processing Record 35 of Set 5 | qaqortoq
# Processing Record 36 of Set 5 | najran
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | mount gambier
# Processing Record 39 of Set 5 | vardo
# Processing Record 40 of Set 5 | mogadishu
# Processing Record 41 of Set 5 | saint-leu
# City not found. Skipping...
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | alexandria
# Processing Record 44 of Set 5 | lavrentiya
# Processing Record 45 of Set 5 | mildura
# Processing Record 46 of Set 5 | atherton
# Processing Record 47 of Set 5 | tilichiki
# City not found. Skipping...
# Processing Record 48 of Set 5 | santa marta
# Processing Record 49 of Set 5 | hun
# Processing Record 0 of Set 6 | biak
# Processing Record 1 of Set 6 | tateyama
# Processing Record 2 of Set 6 | georgetown
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | verkhoyansk
# City not found. Skipping...
# Processing Record 5 of Set 6 | ketchikan
# Processing Record 6 of Set 6 | beyneu
# Processing Record 7 of Set 6 | linxia
# Processing Record 8 of Set 6 | tabou
# Processing Record 9 of Set 6 | nyzhni sirohozy
# Processing Record 10 of Set 6 | kandrian
# Processing Record 11 of Set 6 | arlit
# Processing Record 12 of Set 6 | chapada dos guimaraes
# Processing Record 13 of Set 6 | muisne
# Processing Record 14 of Set 6 | nakasongola
# Processing Record 15 of Set 6 | klaksvik
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | marsa matruh
# Processing Record 19 of Set 6 | port blair
# City not found. Skipping...
# Processing Record 20 of Set 6 | zyryanka
# City not found. Skipping...
# Processing Record 21 of Set 6 | shimoda
# Processing Record 22 of Set 6 | grindavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 6 | teguise
# Processing Record 24 of Set 6 | hirara
# Processing Record 25 of Set 6 | tahe
# Processing Record 26 of Set 6 | nenjiang
# Processing Record 27 of Set 6 | iwanai
# Processing Record 28 of Set 6 | fairbanks
# Processing Record 29 of Set 6 | waipawa
# Processing Record 30 of Set 6 | ponta do sol
# Processing Record 31 of Set 6 | vulturesti
# Processing Record 32 of Set 6 | naze
# Processing Record 33 of Set 6 | liverpool
# Processing Record 34 of Set 6 | mumford
# Processing Record 35 of Set 6 | pisco
# Processing Record 36 of Set 6 | trinidad
# Processing Record 37 of Set 6 | butler
# Processing Record 38 of Set 6 | kuching
# Processing Record 39 of Set 6 | santiago del estero
# Processing Record 40 of Set 6 | hillsborough
# Processing Record 41 of Set 6 | tigil
# Processing Record 42 of Set 6 | gayeri
# Processing Record 43 of Set 6 | rocha
# Processing Record 44 of Set 6 | ammon
# Processing Record 45 of Set 6 | tadine
# Processing Record 46 of Set 6 | caraballeda
# City not found. Skipping...
# Processing Record 47 of Set 6 | lata
# Processing Record 48 of Set 6 | victoria
# Processing Record 49 of Set 6 | rio verde de mato grosso
# Processing Record 0 of Set 7 | colares
# Processing Record 1 of Set 7 | general roca
# Processing Record 2 of Set 7 | yerofey pavlovich
# Processing Record 3 of Set 7 | cap malheureux
# Processing Record 4 of Set 7 | south lake tahoe
# Processing Record 5 of Set 7 | taoudenni
# Processing Record 6 of Set 7 | codrington
# Processing Record 7 of Set 7 | tabuk
# Processing Record 8 of Set 7 | alta floresta
# Processing Record 9 of Set 7 | tual
# Processing Record 10 of Set 7 | port-cartier
# Processing Record 11 of Set 7 | voyvozh
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | uelzen
# Processing Record 14 of Set 7 | swan river
# Processing Record 15 of Set 7 | rodrigues alves
# Processing Record 16 of Set 7 | jishou
# Processing Record 17 of Set 7 | port keats
# Processing Record 18 of Set 7 | vung tau
# Processing Record 19 of Set 7 | havelock
# Processing Record 20 of Set 7 | upernavik
# Processing Record 21 of Set 7 | bilma
# Processing Record 22 of Set 7 | vostok
# Processing Record 23 of Set 7 | pashiya
# Processing Record 24 of Set 7 | nguruka
# Processing Record 25 of Set 7 | longyan
# Processing Record 26 of Set 7 | fort nelson
# Processing Record 27 of Set 7 | belozerskoye
# Processing Record 28 of Set 7 | remanso
# Processing Record 29 of Set 7 | moose factory
# Processing Record 30 of Set 7 | wodonga
# Processing Record 31 of Set 7 | kamenka
# Processing Record 32 of Set 7 | hovd
# Processing Record 33 of Set 7 | aloleng
# Processing Record 34 of Set 7 | margate
# Processing Record 35 of Set 7 | port elizabeth
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | belmonte
# Processing Record 38 of Set 7 | mehamn
# Processing Record 39 of Set 7 | aklavik
# Processing Record 40 of Set 7 | mezen
# Processing Record 41 of Set 7 | sibu
# Processing Record 42 of Set 7 | grand gaube
# Processing Record 43 of Set 7 | koumac
# Processing Record 44 of Set 7 | praya
# Processing Record 45 of Set 7 | havoysund
# Processing Record 46 of Set 7 | san patricio
# Processing Record 47 of Set 7 | sur
# Processing Record 48 of Set 7 | gumdag
# Processing Record 49 of Set 7 | ixtapa
# Processing Record 0 of Set 8 | shelburne
# Processing Record 1 of Set 8 | portland
# Processing Record 2 of Set 8 | danjiangkou
# Processing Record 3 of Set 8 | san pedro
# Processing Record 4 of Set 8 | chivilcoy
# Processing Record 5 of Set 8 | gubkinskiy
# Processing Record 6 of Set 8 | kibala
# Processing Record 7 of Set 8 | saint george
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 8 | high level
# Processing Record 9 of Set 8 | amapa
# Processing Record 10 of Set 8 | rawson
# City not found. Skipping...
# Processing Record 11 of Set 8 | longhua
# Processing Record 12 of Set 8 | zanjan
# Processing Record 13 of Set 8 | marsh harbour
# Processing Record 14 of Set 8 | chervonohryhorivka
# Processing Record 15 of Set 8 | salalah
# Processing Record 16 of Set 8 | acapulco
# Processing Record 17 of Set 8 | mogwase
# Processing Record 18 of Set 8 | evanston
# Processing Record 19 of Set 8 | college
# Processing Record 20 of Set 8 | saint anthony
# Processing Record 21 of Set 8 | fortuna
# Processing Record 22 of Set 8 | carnarvon
# Processing Record 23 of Set 8 | vestmannaeyjar
# Processing Record 24 of Set 8 | shihezi
# Processing Record 25 of Set 8 | inhambane
# Processing Record 26 of Set 8 | isangel
# Processing Record 27 of Set 8 | qingdao
# Processing Record 28 of Set 8 | gejiu
# Processing Record 29 of Set 8 | freeport
# Processing Record 30 of Set 8 | bograd
# City not found. Skipping...
# Processing Record 31 of Set 8 | arari
# Processing Record 32 of Set 8 | launceston
# Processing Record 33 of Set 8 | ubinskoye
# Processing Record 34 of Set 8 | san carlos de bariloche
# Processing Record 35 of Set 8 | santo antonio do ica
# Processing Record 36 of Set 8 | koutsouras
# Processing Record 37 of Set 8 | duluth
# Processing Record 38 of Set 8 | matamoros
# Processing Record 39 of Set 8 | yazoo city
# Processing Record 40 of Set 8 | havre-saint-pierre
# Processing Record 41 of Set 8 | lasa
# Processing Record 42 of Set 8 | luanda
# Processing Record 43 of Set 8 | quatre cocos
# City not found. Skipping...
# Processing Record 44 of Set 8 | nioro
# City not found. Skipping...
# Processing Record 45 of Set 8 | sawakin
# Processing Record 46 of Set 8 | sakaiminato
# Processing Record 47 of Set 8 | khani
# City not found. Skipping...
# Processing Record 48 of Set 8 | port said
# Processing Record 49 of Set 8 | porto novo
# Processing Record 0 of Set 9 | antofagasta
# Processing Record 1 of Set 9 | urengoy
# Processing Record 2 of Set 9 | zdvinsk
# Processing Record 3 of Set 9 | banepa
# Processing Record 4 of Set 9 | saint-augustin
# Processing Record 5 of Set 9 | kendari
# Processing Record 6 of Set 9 | purranque
# Processing Record 7 of Set 9 | ichnya
# Processing Record 8 of Set 9 | marabba
# Processing Record 9 of Set 9 | maibong
# Processing Record 10 of Set 9 | chuguyevka
# Processing Record 11 of Set 9 | sinaloa
# Processing Record 12 of Set 9 | udachnyy
# Processing Record 13 of Set 9 | pochutla
# Processing Record 14 of Set 9 | kalmunai
# Processing Record 15 of Set 9 | sao filipe
# Processing Record 16 of Set 9 | mackenzie
# Processing Record 17 of Set 9 | cedar city
# Processing Record 18 of Set 9 | nagorsk
# Processing Record 19 of Set 9 | masuguru
# Processing Record 20 of Set 9 | shitanjing
# Processing Record 21 of Set 9 | venado tuerto
# Processing Record 22 of Set 9 | lubango
# Processing Record 23 of Set 9 | council bluffs
# City not found. Skipping...
# Processing Record 24 of Set 9 | guilin
# Processing Record 25 of Set 9 | marovoay
# Processing Record 26 of Set 9 | palu
# Processing Record 27 of Set 9 | puerto el triunfo
# Processing Record 28 of Set 9 | arroyo
# Processing Record 29 of Set 9 | leshukonskoye
# Processing Record 30 of Set 9 | monteprandone
# Processing Record 31 of Set 9 | tarabuco
# Processing Record 32 of Set 9 | seoul
# Processing Record 33 of Set 9 | melo
# Processing Record 34 of Set 9 | port lincoln
# Processing Record 35 of Set 9 | gushikawa
# Processing Record 36 of Set 9 | melnikovo
# Processing Record 37 of Set 9 | baracoa
# Processing Record 38 of Set 9 | wuxi
# Processing Record 39 of Set 9 | roma
# Processing Record 40 of Set 9 | madras
# Processing Record 41 of Set 9 | le vauclin
# Processing Record 42 of Set 9 | west freehold
# Processing Record 43 of Set 9 | whitehaven
# Processing Record 44 of Set 9 | meulaboh
# Processing Record 45 of Set 9 | kollo
# Processing Record 46 of Set 9 | yanam
# Processing Record 47 of Set 9 | henties bay
# Processing Record 48 of Set 9 | kiruna
# Processing Record 49 of Set 9 | sibolga
# Processing Record 0 of Set 10 | ambulu
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | ravar
# Processing Record 3 of Set 10 | jalu
# Processing Record 4 of Set 10 | kasongo-lunda
# Processing Record 5 of Set 10 | nantucket
# Processing Record 6 of Set 10 | nhulunbuy
# Processing Record 7 of Set 10 | sandusky
# Processing Record 8 of Set 10 | maldonado
# City not found. Skipping...
# Processing Record 9 of Set 10 | te anau
# Processing Record 10 of Set 10 | halifax
# Processing Record 11 of Set 10 | new norfolk
# Processing Record 12 of Set 10 | sao felix do xingu
# City not found. Skipping...
# Processing Record 13 of Set 10 | krasnoshchekovo
# Processing Record 14 of Set 10 | florianopolis
# Processing Record 15 of Set 10 | boende
# Processing Record 16 of Set 10 | rocky mountain house
# Processing Record 17 of Set 10 | palana
# City not found. Skipping...
# Processing Record 18 of Set 10 | kavaratti
# Processing Record 19 of Set 10 | baruun-urt
# Processing Record 20 of Set 10 | fort beaufort
# City not found. Skipping...
# Processing Record 21 of Set 10 | shikarpur
# Processing Record 22 of Set 10 | bayji
# Processing Record 23 of Set 10 | westport
# Processing Record 24 of Set 10 | moron
# Processing Record 25 of Set 10 | alugan
# Processing Record 26 of Set 10 | elizabeth city
# Processing Record 27 of Set 10 | filadelfia
# Processing Record 28 of Set 10 | carballo
# Processing Record 29 of Set 10 | pilar
# Processing Record 30 of Set 10 | umm lajj
# Processing Record 31 of Set 10 | ormara
# Processing Record 32 of Set 10 | kindu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 10 | tocopilla
# Processing Record 34 of Set 10 | anito
# Processing Record 35 of Set 10 | alcaniz
# Processing Record 36 of Set 10 | pangnirtung
# Processing Record 37 of Set 10 | cockburn town
# Processing Record 38 of Set 10 | hobyo
# Processing Record 39 of Set 10 | vetlanda
# Processing Record 40 of Set 10 | kenai
# Processing Record 41 of Set 10 | presidencia roque saenz pena
# Processing Record 42 of Set 10 | basco
# Processing Record 43 of Set 10 | port augusta
# Processing Record 44 of Set 10 | sirjan
# Processing Record 45 of Set 10 | concepcion del oro
# Processing Record 46 of Set 10 | jumla
# City not found. Skipping...
# Processing Record 47 of Set 10 | cayenne
# Processing Record 48 of Set 10 | bijar
# Processing Record 49 of Set 10 | atar
# Processing Record 0 of Set 11 | lufilufi
# Processing Record 1 of Set 11 | winnemucca
# Processing Record 2 of Set 11 | dingtao
# Processing Record 3 of Set 11 | herat
# Processing Record 4 of Set 11 | kununurra
# Processing Record 5 of Set 11 | atasu
# Processing Record 6 of Set 11 | ponta delgada
# Processing Record 7 of Set 11 | hualmay
# Processing Record 8 of Set 11 | bambanglipuro
# Processing Record 9 of Set 11 | shamary
# Processing Record 10 of Set 11 | nicoya
# Processing Record 11 of Set 11 | puerto suarez
# Processing Record 12 of Set 11 | dali
# Processing Record 13 of Set 11 | borazjan
# Processing Record 14 of Set 11 | banfora
# Processing Record 15 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 11 | san antonio
# Processing Record 17 of Set 11 | mabay
# Processing Record 18 of Set 11 | sulecin
# City not found. Skipping...
# Processing Record 19 of Set 11 | aykhal
# Processing Record 20 of Set 11 | mandalgovi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 11 | jauja
# Processing Record 22 of Set 11 | kutum
# Processing Record 23 of Set 11 | kupang
# Processing Record 24 of Set 11 | villamontes
# Processing Record 25 of Set 11 | lorengau
# Processing Record 26 of Set 11 | alice springs
# Processing Record 27 of Set 11 | vajszlo
# Processing Record 28 of Set 11 | muros
# City not found. Skipping...
# Processing Record 29 of Set 11 | ouadda
# Processing Record 30 of Set 11 | iracoubo
# Processing Record 31 of Set 11 | adrar
# City not found. Skipping...
# Processing Record 32 of Set 11 | chara
# Processing Record 33 of Set 11 | lahij
# Processing Record 34 of Set 11 | dharchula
# City not found. Skipping...
# Processing Record 35 of Set 11 | torbat-e jam
# Processing Record 36 of Set 11 | abu road
# Processing Record 37 of Set 11 | vanavara
# Processing Record 38 of Set 11 | lebedinyy
# Processing Record 39 of Set 11 | neuquen
# City not found. Skipping...
# Processing Record 40 of Set 11 | saint-ambroise
# Processing Record 41 of Set 11 | sayyan
# Processing Record 42 of Set 11 | okhotsk
# Processing Record 43 of Set 11 | shuyskoye
# Processing Record 44 of Set 11 | los llanos de aridane
# Processing Record 45 of Set 11 | samana
# Processing Record 46 of Set 11 | riviere-du-loup
# Processing Record 47 of Set 11 | yaqui
# Processing Record 48 of Set 11 | komsomolskiy
# Processing Record 49 of Set 11 | arcani
# Processing Record 0 of Set 12 | chadiza
# Processing Record 1 of Set 12 | sirnak
# Processing Record 2 of Set 12 | san ramon
# Processing Record 3 of Set 12 | nynashamn
# City not found. Skipping...
# Processing Record 4 of Set 12 | nouadhibou
# Processing Record 5 of Set 12 | neon monastirion
# Processing Record 6 of Set 12 | nelson bay
# Processing Record 7 of Set 12 | edd
# Processing Record 8 of Set 12 | bassar
# Processing Record 9 of Set 12 | mahajanga
# Processing Record 10 of Set 12 | kathu
# Processing Record 11 of Set 12 | boyolangu
# Processing Record 12 of Set 12 | byron bay
# Processing Record 13 of Set 12 | darhan
# Processing Record 14 of Set 12 | porto de moz
# Processing Record 15 of Set 12 | rawalpindi
# City not found. Skipping...
# Processing Record 16 of Set 12 | blythe
# Processing Record 17 of Set 12 | saint-georges
# Processing Record 18 of Set 12 | mason city
# Processing Record 19 of Set 12 | dzhebariki-khaya
# Processing Record 20 of Set 12 | dakar
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = weather_df.mask(weather_df.eq('None')).dropna()
weather_df = weather_df.reset_index(drop=True)
weather_df.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat    Long Max Temp  \
# 0  busselton         54      AU  1566688822       65 -33.64  115.35       45
# 1      roald        100      NO  1566688824       60  62.58    6.12       68
# 2   ashqelon         20      IL  1566688826       78  31.67   34.57     80.6
# 3   cam ranh         20      VN  1566688827       83  11.92  109.15     82.4
# 4   lantawan         75      PH  1566688828       74  10.57  123.77     82.4
#
#   Wind Speed
# 0      11.39
# 1      12.75
# 2        4.7
# 3       2.24
# 4       3.36

# %%
weather_df.to_csv('weather_data.csv', index = False) #saves to csv

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#creates scatter plot for lat and temp and then saves it
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", edgecolor='black')
plt.title("City Latitude vs Max Temperature (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig('Pictures/Lat_Temp_Plot.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#creates scatter plot for lat and humidity and then saves it
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", edgecolor='black')
plt.title("City Latitude vs Humidity (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig('Pictures/Lat_Humidity_Plot.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#creates scatter plot for lat and cloudiness and then saves it
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", edgecolor='black')
plt.title("City Latitude vs Cloudiness (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig('Pictures/Lat_Cloudiness_Plot.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#creates scatter plot for lat and wind speed and then saves it
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", edgecolor='black')
plt.title("City Latitude vs Wind Speed (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig('Pictures/Lat_Wind_Plot.png')

# %% [markdown]
# ### Data Observations

# %% [markdown]
# 1. As the latitude approaches zero, from both the positive and negative directions, the temperature rises. As you move farther away from 0, it begins to fall.
# 2. The majority of cities had a humidity above 40%, but there is no reletionship between humidity and latitude.
# 3. The majority of cities had a wind speed below 10mph, but there is no relationship between wind speed and latitude.
# 4. There is no observable trend between cloudiness and latitude.
