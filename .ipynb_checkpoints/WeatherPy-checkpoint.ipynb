# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from pprint import pprint
from urllib.error import HTTPError

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
long_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_longs and cities
lat_longs = []
cities = []

# Create a set of random lat and long combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
longs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_longs = zip(lats, longs)

# Identify nearest city for each lat, long combination
for lat_long in lat_longs:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
settings = {"units": "imperial", "appid": api_key}

# %%
weather = [] #array that will hold the data pulled from the get request for each city
i = 0 #use i as counter for record number since idexes may not match the record number if we skip a record
print("Beginning Data Retrieval")
print("------------------------") 
for x in range(len(cities)):
    #tries to get request the weather for the current city, appends info, and prints processing record number and city name
    try:
        current_weather= owm.get_current(cities[x], **settings)
        weather.append(current_weather)
        print(f"Processing Record {i%50} of Set {i//50 +1} | {cities[x]}")
        i = i + 1
    #if gets HTTPError because no data for that city, will print city not found and continues on
    except HTTPError:
        print(f"City not found. Skipping...")
    time.sleep(1)
print("------------------------")  
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 1 | port augusta
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | alakurtti
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | mocuba
# Processing Record 10 of Set 1 | new norfolk
# Processing Record 11 of Set 1 | ayan
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | gusinoye ozero
# Processing Record 14 of Set 1 | namibe
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | takoradi
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | oktyabrskoye
# Processing Record 21 of Set 1 | ilulissat
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#lists for all the data we want
cloudiness = []
country = []
date = []
humidity =[]
lat = []
long = []
max_temp = []
wind_speed = []
cities_found = []

#for each city, pulls info we want and appends to appropriate list. then moves on to next city
for i in range(len(weather)):
    cities_found_current = weather[i]["name"]
    cities_found.append(cities_found_current)
    
    clouds_current = weather[i]["clouds"]["all"]
    cloudiness.append(clouds_current)
    
    country_current = weather[i]["sys"]["country"]
    country.append(country_current)
    
    date_current = weather[i]["dt"]
    date.append(date_current)
    
    humidity_current = weather[i]["main"]["humidity"]
    humidity.append(humidity_current)
    
    lat_current = weather[i]["coord"]["lat"]
    lat.append(lat_current)
    
    long_current = weather[i]["coord"]["lon"]
    long.append(long_current)
    
    max_temp_current  = weather[i]["main"]["temp_max"]
    max_temp.append(max_temp_current)
    
    wind_speed_current = weather[i]["wind"]["speed"]
    wind_speed.append(wind_speed_current)

# %%
#combines info into a dictionary
weather_dict = {
    "City": cities_found,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Long": long,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# %%
#converst dictionary to a data frame and print out the counts
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          543
# Cloudiness    543
# Country       543
# Date          543
# Humidity      543
# Lat           543
# Long          543
# Max Temp      543
# Wind Speed    543
# dtype: int64

# %%
weather_data.to_csv('weather_data.csv', index = False) #saves to csv

# %%
weather_data.head() #prints first five lines
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat    Long  \
# 0  Port Augusta           0      AU  1566604826        33 -32.49  137.76
# 1        Hobart          40      AU  1566604684        47 -42.88  147.33
# 2     Alakurtti         100      RU  1566604917        91  66.96   30.34
# 3  Punta Arenas          90      CL  1566604918        93 -53.16  -70.91
# 4        Barrow          98      AR  1566604920        62 -38.31  -60.23
#
#    Max Temp  Wind Speed
# 0     62.60       19.46
# 1     57.99       13.87
# 2     48.00        1.99
# 3     41.00       11.41
# 4     51.52        9.17

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#creates scatter plot for lat and temp and then saves it
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", edgecolor='black')
plt.title("City Latitude vs Max Temperature (08/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig('Pictures/Lat_Temp_Plot.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#creates scatter plot for lat and humidity and then saves it
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", edgecolor='black')
plt.title("City Latitude vs Humidity (08/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig('Pictures/Lat_Humidity_Plot.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#creates scatter plot for lat and cloudiness and then saves it
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", edgecolor='black')
plt.title("City Latitude vs Cloudiness (08/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig('Pictures/Lat_Cloudiness_Plot.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#creates scatter plot for lat and wind speed and then saves it
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", edgecolor='black')
plt.title("City Latitude vs Wind Speed (08/23/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig('Pictures/Lat_Wind_Plot.png')

# %% [markdown]
# ### Data Observations

# %% [markdown]
# 1. As the latitude approaches zero, from both the positive and negative directions, the temperature rises. As you move farther away from 0, it begins to fall.
# 2. The majority of cities had a humidity above 40%, but there is no reletionship between humidity and latitude.
# 3. The majority of cities had a wind speed below 10mph, but there is no relationship between wind speed and latitude.
# 4. There is no observable trend between cloudiness and latitude.
